# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import *

from fund_tools import *

# %%
today = datetime.today()
today
# Out:
# datetime.datetime(2021, 12, 28, 18, 33, 39, 618323)

# %%
zolh = get_fund_net_worth('001980','2021-09-14', today, 'open')
zssw = get_fund_net_worth('161726','2021-11-11', today, 'open')
cyzs = get_fund_net_worth('006928','2021-07-27', today, 'open')

nfkz = get_fund_net_worth('000997','2021-10-27', today, 'open')
nfsz = get_fund_net_worth('005461','2021-10-19', today, 'open')
zfdzz = get_fund_net_worth('003358','2021-11-25', today, 'open')

# %%
zfdzz
# Out:
#           净值日期    单位净值  日增长率
# 0   2021-11-25  1.1525  0.01
# 1   2021-11-26  1.1545  0.17
# 2   2021-11-29  1.1546  0.01
# 3   2021-11-30  1.1551  0.04
# 4   2021-12-01  1.1544 -0.06
# 5   2021-12-02  1.1538 -0.05
# 6   2021-12-03  1.1533 -0.04
# 7   2021-12-06  1.1571  0.33
# 8   2021-12-07  1.1553 -0.16
# 9   2021-12-08  1.1548 -0.04
# 10  2021-12-09  1.1553  0.04
# 11  2021-12-10  1.1565  0.10
# 12  2021-12-13  1.1567  0.02
# 13  2021-12-14  1.1580  0.11
# 14  2021-12-15  1.1586  0.05
# 15  2021-12-16  1.1588  0.02
# 16  2021-12-17  1.1593  0.04
# 17  2021-12-20  1.1596  0.03
# 18  2021-12-21  1.1596  0.00
# 19  2021-12-22  1.1606  0.09
# 20  2021-12-23  1.1615  0.08
# 21  2021-12-24  1.1617  0.02
# 22  2021-12-27  1.1628  0.09
# 23  2021-12-28  1.1638  0.09
